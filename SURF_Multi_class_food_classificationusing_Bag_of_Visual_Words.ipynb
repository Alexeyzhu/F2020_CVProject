# %%
from IPython.display import clear_output
# !pip install opencv-python==3.4.2.16
# !pip install opencv-contrib-python==3.4.2.16
clear_output()

# %%
import cv2
import numpy as np
import os
import pickle
from pathlib import Path
import glob
# import string
import matplotlib.pyplot as plt
# import random
from tqdm import tqdm 
# from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import MiniBatchKMeans
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import plot_confusion_matrix, accuracy_score, f1_score
from sklearn import svm
# %matplotlib inline

# %%
cv2.__version__
# Out:
# '3.4.2'

# %% [markdown]
# ## 1. Data preprocessing

# %% [markdown]
# #### Download dataset

# %%
# !git clone "https://github.com/Horea94/Fruit-Images-Dataset.git" "/tmp/input"
# Out:
# fatal: destination path '/tmp/input' already exists and is not an empty directory.

# %% [markdown]
# #### Split dataset

# %%
def getYourFruits(fruits, data_split, print_n=False, k_fold=False):
    images = []
    labels = []
    val = ['Training', 'Test']

    path = Path("/tmp/input/") / data_split
    if print_n: 
      print(f'\nThere are {len(os.listdir(path))} classes in {path}')

    for i, fruit in enumerate(fruits):
        p = path / fruit
        j=0
        for image_path in p.glob("*.jpg"):
            image = cv2.imread(str(image_path), cv2.IMREAD_COLOR)
            image = cv2.resize(image, (dim, dim))
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
            images.append(image)
            labels.append(i)
            j+=1
        if(print_n):
            print(f"There are {j} {data_split.upper()} images of {fruits[i].upper()}")
    images = np.array(images)
    labels = np.array(labels)
    return images, labels
    
def getAllFruits():
    fruits = []
    for fruit_path in glob.glob("/tmp/input/Training/*"):
        fruit = fruit_path.split("/")[-1]
        fruits.append(fruit)
    return fruits

# %% [markdown]
# #### Visualize dataset

# %%
def plot_image_grid(images, text, nb_rows, nb_cols, figsize=(15, 15)):
    assert len(images) == nb_rows*nb_cols, "Number of images should be the same as (nb_rows*nb_cols)"
    fig, axs = plt.subplots(nb_rows, nb_cols, figsize=figsize)
    
    n = 0
    for i in range(0, nb_rows):
        for j in range(0, nb_cols):
            axs[i, j].axis('off')
            axs[i, j].title.set_text(text[n])
            axs[i, j].imshow(images[n])
            n += 1

# %% [markdown]
# ## 2. SIFT-BOVW pipeline

# %%
def computeFeatures(extractor, images):
  keypoints = []
  descriptors = []
  des_imgs = []
  for img in tqdm(images):
    kp, des = extractor.detectAndCompute(img, None)

    keypoints.append(kp)
    des_imgs.append(des)
    
    if des is not None:
      for d in des:
        descriptors.append(d)

  return np.array(keypoints), np.array(descriptors), np.array(des_imgs)

# %% [markdown]
# ## 3. Classification of feature-vectors

# %%
def clustering(k, labels, descriptors):
  batch_size = int(len(labels) / 5)
  kmeans = MiniBatchKMeans(n_clusters=k, batch_size=batch_size, verbose=0, random_state=0)
  kmeans = kmeans.fit(descriptors)
  return kmeans

# %%
def histograms(k, clusters, kps, image_des):
  clusters.verbose = False

  histo_list = []
  delete_index = []

  for iter in tqdm(range(image_des.shape[0])):
      histo = np.zeros(k)
      nkp = np.size(kps[iter])

      if image_des[iter] is not None:
        for d in image_des[iter]:
            idx = clusters.predict([d])
            histo[idx] += 1/nkp 

        histo_list.append(histo)
      else:
        delete_index.append(iter)
    
  return np.array(histo_list), delete_index

# %% [markdown]
# ## 4. Hyperparameters tuning

# %%
def fit(model, X, Y):
  model.fit(X, Y)
  return model

# %%
def predict(model, images, clusters, extractor, proba=True):
  preds = []
  y = []

  delete_index = []

  for i in range(len(images)):
      kp, des = extractor.detectAndCompute(images[i], None)

      x = np.zeros(k)
      nkp = np.size(kp)

      if des is not None:
        for d in des:
            idx = clusters.predict([d])
            x[idx] += 1/nkp

        y.append(x)

        if proba:
          res = model.predict_proba([x])
          preds.append(np.argmax(res))
        else:
          res = model.predict([x])
          preds.append(res)
      else:
        delete_index.append(i)

  return preds, y, delete_index

# %% [markdown]
# # 5. Results

# %%
# Example for multiclass classification on all the training data
dim = 100 #image height, width
fruits = getAllFruits() 

#Get Images and Labels 
X_train_img, y_train =  getYourFruits(fruits, 'Training', print_n=False, k_fold=False)
X_test_img, y_test = getYourFruits(fruits, 'Test', print_n=False, k_fold=False)

# %%
print(X_train_img.shape)
print(X_test_img.shape)
# Out:
# (67692, 100, 100, 3)
# (22688, 100, 100, 3)

# %%
# X_train_img = X_train_img[:1000]
# y_train = y_train[:1000]
# X_test_img = X_test_img[:1000]
# y_test = y_test[:1000]

# %%
surf = cv2.xfeatures2d.SURF_create()

# %%
keypoints_surf, descriptors_surf, des_imgs_surf = computeFeatures(surf, X_train_img)
print(descriptors_surf.shape)
# Out:
# 100%|██████████| 67692/67692 [03:45<00:00, 299.88it/s]
# (1878630, 64)

# %%
inds = [0, 4002, 5006, 7500, 10000, 15000, 25600, 35000]
ncol, nrows = 2, 4
text = [fruits[y_train[i]] for i in inds]

print('SURF')
drawImg = []

for i in inds:
  drawImg.append(cv2.drawKeypoints(X_train_img[i], keypoints_surf[i], 
                      None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS))

plot_image_grid(drawImg, text, ncol, nrows, figsize=(10, 10))
# Out:
# SURF

# %%
k = len(fruits) * 10

# %%
kmeans_surf = clustering(k, fruits, descriptors_surf)

clear_output()

# %%
histo_list_surf, delete_index  = histograms(k, kmeans_surf, keypoints_surf, des_imgs_surf)
# Out:
# 100%|██████████| 67692/67692 [49:05<00:00, 22.98it/s]

# %%
y_train = np.delete(y_train, delete_index)

# %%
# clf_sift = svm.LinearSVR(verbose=1)

# %%
# clf_surf = fit(clf_surf, histo_list_surf, y_train)

# %%
mlp_surf = MLPClassifier(verbose=True, max_iter=600)

# %%
mlp_surf = fit(mlp_surf, histo_list_surf, y_train)
# Out:
# Iteration 1, loss = 4.52904519
# Iteration 2, loss = 3.30390661
# Iteration 3, loss = 2.55384856
# Iteration 4, loss = 2.12731212
# Iteration 5, loss = 1.85159403
# Iteration 6, loss = 1.65779496
# Iteration 7, loss = 1.50943279
# Iteration 8, loss = 1.39014449
# Iteration 9, loss = 1.29109819
# Iteration 10, loss = 1.20519223
# Iteration 11, loss = 1.13174391
# Iteration 12, loss = 1.06632608
# Iteration 13, loss = 1.00864961
# Iteration 14, loss = 0.95680193
# Iteration 15, loss = 0.91007091
# Iteration 16, loss = 0.86817934
# Iteration 17, loss = 0.82929113
# Iteration 18, loss = 0.79468664
# Iteration 19, loss = 0.76209629
# Iteration 20, loss = 0.73192570
# Iteration 21, loss = 0.70465335
# Iteration 22, loss = 0.67915780
# Iteration 23, loss = 0.65529623
# Iteration 24, loss = 0.63332382
# Iteration 25, loss = 0.61237789
# Iteration 26, loss = 0.59295827
# Iteration 27, loss = 0.57486153
# Iteration 28, loss = 0.55767811
# Iteration 29, loss = 0.54178649
# Iteration 30, loss = 0.52598270
# Iteration 31, loss = 0.51197264
# Iteration 32, loss = 0.49845196
# Iteration 33, loss = 0.48520853
# Iteration 34, loss = 0.47267139
# Iteration 35, loss = 0.46107498
# Iteration 36, loss = 0.44958530
# Iteration 37, loss = 0.43960295
# Iteration 38, loss = 0.42920501
# Iteration 39, loss = 0.41967962
# Iteration 40, loss = 0.41041158
# Iteration 41, loss = 0.40164058
# Iteration 42, loss = 0.39301694
# Iteration 43, loss = 0.38530762
# Iteration 44, loss = 0.37736326
# Iteration 45, loss = 0.36990475
# Iteration 46, loss = 0.36244607
# Iteration 47, loss = 0.35574973
# Iteration 48, loss = 0.34966903
# Iteration 49, loss = 0.34277598
# Iteration 50, loss = 0.33676964
# Iteration 51, loss = 0.33101685
# Iteration 52, loss = 0.32532987
# Iteration 53, loss = 0.31968313
# Iteration 54, loss = 0.31473507
# Iteration 55, loss = 0.30947708
# Iteration 56, loss = 0.30443058
# Iteration 57, loss = 0.29956664
# Iteration 58, loss = 0.29525670
# Iteration 59, loss = 0.29057416
# Iteration 60, loss = 0.28662136
# Iteration 61, loss = 0.28200183
# Iteration 62, loss = 0.27778308
# Iteration 63, loss = 0.27413158
# Iteration 64, loss = 0.27039878
# Iteration 65, loss = 0.26701915
# Iteration 66, loss = 0.26338674
# Iteration 67, loss = 0.25977386
# Iteration 68, loss = 0.25619842
# Iteration 69, loss = 0.25298560
# Iteration 70, loss = 0.25003629
# Iteration 71, loss = 0.24697973
# Iteration 72, loss = 0.24400381
# Iteration 73, loss = 0.24105575
# Iteration 74, loss = 0.23807289
# Iteration 75, loss = 0.23534834
# Iteration 76, loss = 0.23267529
# Iteration 77, loss = 0.23006258
# Iteration 78, loss = 0.22740841
# Iteration 79, loss = 0.22522013
# Iteration 80, loss = 0.22265025
# Iteration 81, loss = 0.22040497
# Iteration 82, loss = 0.21788714
# Iteration 83, loss = 0.21592603
# Iteration 84, loss = 0.21365341
# Iteration 85, loss = 0.21163082
# Iteration 86, loss = 0.20940804
# Iteration 87, loss = 0.20735100
# Iteration 88, loss = 0.20550489
# Iteration 89, loss = 0.20350623
# Iteration 90, loss = 0.20177392
# Iteration 91, loss = 0.19980054
# Iteration 92, loss = 0.19790294
# Iteration 93, loss = 0.19628599
# Iteration 94, loss = 0.19438519
# Iteration 95, loss = 0.19286599
# Iteration 96, loss = 0.19132474
# Iteration 97, loss = 0.18956025
# Iteration 98, loss = 0.18808272
# Iteration 99, loss = 0.18655963
# Iteration 100, loss = 0.18503000
# Iteration 101, loss = 0.18344334
# Iteration 102, loss = 0.18204576
# Iteration 103, loss = 0.18062666
# Iteration 104, loss = 0.17937461
# Iteration 105, loss = 0.17786778
# Iteration 106, loss = 0.17667050
# Iteration 107, loss = 0.17568384
# Iteration 108, loss = 0.17416802
# Iteration 109, loss = 0.17300085
# Iteration 110, loss = 0.17196863
# Iteration 111, loss = 0.17062012
# Iteration 112, loss = 0.16962741
# Iteration 113, loss = 0.16844629
# Iteration 114, loss = 0.16719406
# Iteration 115, loss = 0.16598282
# Iteration 116, loss = 0.16495471
# Iteration 117, loss = 0.16404330
# Iteration 118, loss = 0.16299177
# Iteration 119, loss = 0.16190918
# Iteration 120, loss = 0.16098482
# Iteration 121, loss = 0.15987177
# Iteration 122, loss = 0.15902636
# Iteration 123, loss = 0.15825699
# Iteration 124, loss = 0.15698359
# Iteration 125, loss = 0.15625606
# Iteration 126, loss = 0.15513011
# Iteration 127, loss = 0.15417543
# Iteration 128, loss = 0.15337953
# Iteration 129, loss = 0.15291898
# Iteration 130, loss = 0.15181731
# Iteration 131, loss = 0.15120760
# Iteration 132, loss = 0.14996768
# Iteration 133, loss = 0.14931015
# Iteration 134, loss = 0.14871917
# Iteration 135, loss = 0.14793414
# Iteration 136, loss = 0.14704800
# Iteration 137, loss = 0.14640903
# Iteration 138, loss = 0.14554520
# Iteration 139, loss = 0.14503697
# Iteration 140, loss = 0.14417600
# Iteration 141, loss = 0.14343495
# Iteration 142, loss = 0.14300729
# Iteration 143, loss = 0.14204695
# Iteration 144, loss = 0.14162964
# Iteration 145, loss = 0.14076933
# Iteration 146, loss = 0.14016594
# Iteration 147, loss = 0.13957974
# Iteration 148, loss = 0.13914759
# Iteration 149, loss = 0.13839308
# Iteration 150, loss = 0.13765513
# Iteration 151, loss = 0.13704640
# Iteration 152, loss = 0.13660491
# Iteration 153, loss = 0.13599739
# Iteration 154, loss = 0.13556056
# Iteration 155, loss = 0.13470567
# Iteration 156, loss = 0.13411379
# Iteration 157, loss = 0.13375607
# Iteration 158, loss = 0.13315233
# Iteration 159, loss = 0.13261358
# Iteration 160, loss = 0.13217352
# Iteration 161, loss = 0.13161282
# Iteration 162, loss = 0.13102598
# Iteration 163, loss = 0.13030804
# Iteration 164, loss = 0.13006752
# Iteration 165, loss = 0.12949581
# Iteration 166, loss = 0.12882362
# Iteration 167, loss = 0.12846015
# Iteration 168, loss = 0.12797455
# Iteration 169, loss = 0.12752483
# Iteration 170, loss = 0.12713451
# Iteration 171, loss = 0.12650254
# Iteration 172, loss = 0.12615381
# Iteration 173, loss = 0.12573890
# Iteration 174, loss = 0.12518469
# Iteration 175, loss = 0.12481874
# Iteration 176, loss = 0.12441356
# Iteration 177, loss = 0.12402020
# Iteration 178, loss = 0.12364812
# Iteration 179, loss = 0.12322190
# Iteration 180, loss = 0.12280718
# Iteration 181, loss = 0.12235520
# Iteration 182, loss = 0.12198274
# Iteration 183, loss = 0.12155549
# Iteration 184, loss = 0.12117951
# Iteration 185, loss = 0.12070980
# Iteration 186, loss = 0.12035505
# Iteration 187, loss = 0.11999838
# Iteration 188, loss = 0.11951417
# Iteration 189, loss = 0.11909034
# Iteration 190, loss = 0.11873158
# Iteration 191, loss = 0.11835435
# Iteration 192, loss = 0.11825080
# Iteration 193, loss = 0.11755461
# Iteration 194, loss = 0.11759378
# Iteration 195, loss = 0.11694289
# Iteration 196, loss = 0.11671845
# Iteration 197, loss = 0.11644649
# Iteration 198, loss = 0.11601996
# Iteration 199, loss = 0.11579118
# Iteration 200, loss = 0.11522444
# Iteration 201, loss = 0.11507060
# Iteration 202, loss = 0.11473617
# Iteration 203, loss = 0.11438987
# Iteration 204, loss = 0.11405622
# Iteration 205, loss = 0.11390328
# Iteration 206, loss = 0.11355282
# Iteration 207, loss = 0.11307535
# Iteration 208, loss = 0.11279148
# Iteration 209, loss = 0.11265959
# Iteration 210, loss = 0.11226941
# Iteration 211, loss = 0.11190415
# Iteration 212, loss = 0.11178932
# Iteration 213, loss = 0.11139050
# Iteration 214, loss = 0.11106579
# Iteration 215, loss = 0.11088880
# Iteration 216, loss = 0.11048208
# Iteration 217, loss = 0.11029969
# Iteration 218, loss = 0.11015440
# Iteration 219, loss = 0.10977349
# Iteration 220, loss = 0.10932456
# Iteration 221, loss = 0.10905834
# Iteration 222, loss = 0.10881831
# Iteration 223, loss = 0.10871421
# Iteration 224, loss = 0.10840978
# Iteration 225, loss = 0.10835565
# Iteration 226, loss = 0.10784523
# Iteration 227, loss = 0.10766342
# Iteration 228, loss = 0.10739725
# Iteration 229, loss = 0.10700199
# Iteration 230, loss = 0.10684393
# Iteration 231, loss = 0.10672168
# Iteration 232, loss = 0.10652927
# Iteration 233, loss = 0.10604990
# Iteration 234, loss = 0.10597482
# Iteration 235, loss = 0.10580575
# Iteration 236, loss = 0.10544346
# Iteration 237, loss = 0.10532318
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:573: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")

# %%
# save the model to disk
kmeans_surf_filename = 'kmeans_surf.pkl'
mlp_surf_filename = 'mlp_surf.pkl'
# clf_surf_filename = 'clf_surf.pkl'

# %%
pickle.dump(kmeans_surf, open(kmeans_surf_filename, 'wb'))
pickle.dump(mlp_surf, open(mlp_surf_filename, 'wb'))
# pickle.dump(clf_surf, open(clf_surf_filename, 'wb'))

# %%
# load the model from disk
kmeans_surf = pickle.load(open(kmeans_surf_filename, 'rb'))
mlp_surf = pickle.load(open(mlp_surf_filename, 'rb'))
# clf_surf = pickle.load(open(clf_surf_filename, 'rb'))

# %%
y_pred_mlp_surf, y_mlp_surf, delete_index = predict(mlp_surf, X_test_img, kmeans_surf, surf)
# y_pred_clf_surf, y_clf_surf = predict(clf_surf, X_test_img, kmeans_surf, surf)

# %%
y_test = np.delete(y_test, delete_index)

# %%
# predicted = [ y_pred_mlp_surf, y_pred_clf_surf]
predicted = [y_pred_mlp_surf]
# methods = ["MLP surf", "SVM surf"]
methods = ["MLP surf"]

# %%
for i in range(len(predicted)):
  print(f"Accuracy {methods[i]}: {accuracy_score(y_test, predicted[i])}")
# Out:
# Accuracy MLP surf: 0.598210349995592

# %%
for i in range(len(predicted)):
  y_pred = predicted[i]
  print(f"F1 score macro {methods[i]}: {f1_score(y_test, y_pred, average='macro')}")
  print(f"F1 score micro {methods[i]}: {f1_score(y_test, y_pred, average='micro')}")
  print(f"F1 score weighted {methods[i]}: {f1_score(y_test, y_pred, average='weighted')}")
# Out:
# F1 score macro MLP surf: 0.5925478163108601
# F1 score micro MLP surf: 0.598210349995592
# F1 score weighted MLP surf: 0.5940734855683975

# %%
inds = [1, 1050, 6560, 9550, 12000, 15000, 18500, 21000]
nrows = 2
ncol = 4

imgs = []
text = []
for i in inds:
  y_pred = predicted[0]
  text.append(f"Pred: {fruits[y_pred[i]]}, True: {fruits[y_test[i]]}")
  imgs.append(X_test_img[i])

plot_image_grid(imgs, text, nrows, ncol, figsize=(20, 20))

# %% [markdown]
# ## References
#
# https://www.kaggle.com/waltermaffy/fruit-classification-pca-svm-knn-decision-tree
